# %% [markdown]
# # GPD Fit and Diagnostics
#
# In this notebook you will fit a Generalised Pareto Distribution (GPD) to the declustered exceedances identified in the previous step. You will use functions from `philflood.ev.gpd_fit` and optionally from the `pyextremes` library to estimate the shape and scale parameters. After fitting, you should produce diagnostic plots (e.g. QQ-plot, return level plot) to assess the quality of the fit and store the fitted parameters for later use.
#
# * **Inputs**: Decluttered exceedance series from Notebook 1.
# * **Outputs**: Fitted GPD parameters and exceedance rate saved to a JSON/YAML file.

# %%
from philflood.ev.gpd_fit import fit_gpd_to_exceedances
from philflood.ev.peaks_over_threshold import extract_declust_pot

# TODO: load declustered exceedances from Notebook 1 (here we use a placeholder)
import pandas as pd
import numpy as np

# Example synthetic exceedances series for illustration
exceedances = pd.Series(np.random.rand(100) + 0.5)
exceedances.index = pd.date_range('2000-01-01', periods=100)

# Choose a threshold used in Notebook 1
threshold = 0.5

# Fit GPD (placeholder implementation)
model = fit_gpd_to_exceedances(exceedances, threshold)
print(f"Fitted GPD parameters: xi={model.shape}, sigma={model.scale}, rate={model.rate}")

# TODO: use pyextremes to fit and diagnose the model properly
